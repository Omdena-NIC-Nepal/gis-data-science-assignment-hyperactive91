# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in c:\users\wlink\omdena\assignment\solutions 5th week\env\lib\site-packages (from -r requirements.txt (line 1)) (2.2.3)
# Collecting geopandas (from -r requirements.txt (line 2))
#   Using cached geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting folium (from -r requirements.txt (line 3))
#   Using cached folium-0.19.5-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting fiona (from -r requirements.txt (line 4))
#   Downloading fiona-1.10.1-cp312-cp312-win_amd64.whl.metadata (58 kB)
# Requirement already satisfied: matplotlib in c:\users\wlink\omdena\assignment\solutions 5th week\env\lib\site-packages (from -r requirements.txt (line 5)) (3.10.0)
# Requirement already satisfied: numpy in c:\users\wlink\omdena\assignment\solutions 5th week\env\lib\site-packages (from -r requirements.txt (line 6)) (2.2.3)
# Collecting shapely (from -r requirements.txt (line 7))
#   Using cached shapely-2.0.7-cp312-cp312-win_amd64.whl.metadata (7.1 kB)
# Collecting rasterio (from -r requirements.txt (line 8))
#   Downloading rasterio-1.4.3-cp312-cp312-win_amd64.whl.metadata (9.4 kB)
# Collecting contextily (from -r requirements.txt (line 9))
#   Downloading contextily-1.6.2-py3-none-any.whl.metadata (2.9 kB)
# Collecting rasterstats (from -r requirements.txt (line 10))
#   Downloading rasterstats-0.20.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting descartes (from -r requirements.txt (line 11))
#   Downloading descartes-1.1.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: seaborn in c:\users\wlink\omdena\assignment\solutions 5th week\env\lib\site-packages (from -r requirements.txt (line 12)) (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\wlink\omdena\assignment\solutions 5th week\env\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\wlink\omdena\assignment\solutions 5th week\env\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\wlink\omdena\assignment\solutions 5th week\env\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2025.1)
# Collecting pyogrio>=0.7.2 (from geopandas->-r requirements.txt (line 2))
#   Using cached pyogrio-0.10.0-cp312-cp312-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging in c:\users\wlink\omdena\assignment\solutions 5th week\env\lib\site-packages (from geopandas->-r requirements.txt (line 2)) (24.2)
# Collecting pyproj>=3.3.0 (from geopandas->-r requirements.txt (line 2))
#   Using cached pyproj-3.7.1-cp312-cp312-win_amd64.whl.metadata (31 kB)
# Collecting branca>=0.6.0 (from folium->-r requirements.txt (line 3))
#   Using cached branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\wlink\omdena\assignment\solutions 5th week\env\lib\site-packages (from folium->-r requirements.txt (line 3)) (3.1.5)
# Collecting requests (from folium->-r requirements.txt (line 3))
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting xyzservices (from folium->-r requirements.txt (line 3))
#   Using cached xyzservices-2025.1.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\wlink\omdena\assignment\solutions 5th week\env\lib\site-packages (from fiona->-r requirements.txt (line 4)) (25.1.0)
# Collecting certifi (from fiona->-r requirements.txt (line 4))
#   Using cached certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting click~=8.0 (from fiona->-r requirements.txt (line 4))
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting click-plugins>=1.0 (from fiona->-r requirements.txt (line 4))
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting cligj>=0.5 (from fiona->-r requirements.txt (line 4))
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\wlink\omdena\assignment\solutions 5th week\env\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\wlink\omdena\assignment\solutions 5th week\env\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\wlink\omdena\assignment\solutions 5th week\env\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\wlink\omdena\assignment\solutions 5th week\env\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\wlink\omdena\assignment\solutions 5th week\env\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\wlink\omdena\assignment\solutions 5th week\env\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (3.2.1)
# Collecting affine (from rasterio->-r requirements.txt (line 8))
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting geopy (from contextily->-r requirements.txt (line 9))
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting mercantile (from contextily->-r requirements.txt (line 9))
#   Downloading mercantile-1.2.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting joblib (from contextily->-r requirements.txt (line 9))
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting simplejson (from rasterstats->-r requirements.txt (line 10))
#   Downloading simplejson-3.20.1-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: colorama in c:\users\wlink\omdena\assignment\solutions 5th week\env\lib\site-packages (from click~=8.0->fiona->-r requirements.txt (line 4)) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\wlink\omdena\assignment\solutions 5th week\env\lib\site-packages (from jinja2>=2.9->folium->-r requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: six>=1.5 in c:\users\wlink\omdena\assignment\solutions 5th week\env\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.17.0)
# Collecting geographiclib<3,>=1.52 (from geopy->contextily->-r requirements.txt (line 9))
#   Downloading geographiclib-2.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting charset-normalizer<4,>=2 (from requests->folium->-r requirements.txt (line 3))
#   Using cached charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests->folium->-r requirements.txt (line 3))
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->folium->-r requirements.txt (line 3))
#   Using cached urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Using cached geopandas-1.0.1-py3-none-any.whl (323 kB)
# Using cached folium-0.19.5-py2.py3-none-any.whl (110 kB)
# Downloading fiona-1.10.1-cp312-cp312-win_amd64.whl (24.5 MB)
#    ---------------------------------------- 0.0/24.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.5 MB ? eta -:--:--
#    - -------------------------------------- 0.8/24.5 MB 2.8 MB/s eta 0:00:09
#    --- ------------------------------------ 1.8/24.5 MB 4.2 MB/s eta 0:00:06
#    --- ------------------------------------ 2.4/24.5 MB 3.7 MB/s eta 0:00:06
#    --- ------------------------------------ 2.4/24.5 MB 3.7 MB/s eta 0:00:06
#    ------ --------------------------------- 3.9/24.5 MB 3.6 MB/s eta 0:00:06
#    --------- ------------------------------ 5.5/24.5 MB 4.3 MB/s eta 0:00:05
#    --------- ------------------------------ 5.5/24.5 MB 4.3 MB/s eta 0:00:05
#    --------- ------------------------------ 5.8/24.5 MB 3.4 MB/s eta 0:00:06
#    ------------ --------------------------- 7.6/24.5 MB 3.9 MB/s eta 0:00:05
#    ------------- -------------------------- 8.4/24.5 MB 4.0 MB/s eta 0:00:05
#    --------------- ------------------------ 9.2/24.5 MB 3.9 MB/s eta 0:00:04
#    ----------------- ---------------------- 10.7/24.5 MB 4.1 MB/s eta 0:00:04
#    ------------------ --------------------- 11.3/24.5 MB 4.2 MB/s eta 0:00:04
#    -------------------- ------------------- 12.6/24.5 MB 4.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 14.4/24.5 MB 4.6 MB/s eta 0:00:03
#    ------------------------- -------------- 15.5/24.5 MB 4.6 MB/s eta 0:00:02
#    --------------------------- ------------ 16.8/24.5 MB 4.6 MB/s eta 0:00:02
#    ------------------------------- -------- 19.1/24.5 MB 5.0 MB/s eta 0:00:02
#    --------------------------------- ------ 20.2/24.5 MB 4.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 21.5/24.5 MB 5.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 21.8/24.5 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  24.1/24.5 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  24.4/24.5 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  24.4/24.5 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 24.5/24.5 MB 4.6 MB/s eta 0:00:00
# Using cached shapely-2.0.7-cp312-cp312-win_amd64.whl (1.4 MB)
# Downloading rasterio-1.4.3-cp312-cp312-win_amd64.whl (25.4 MB)
#    ---------------------------------------- 0.0/25.4 MB ? eta -:--:--
#    - -------------------------------------- 1.0/25.4 MB 7.2 MB/s eta 0:00:04
#    --- ------------------------------------ 2.4/25.4 MB 6.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 3.4/25.4 MB 5.9 MB/s eta 0:00:04
#    ------ --------------------------------- 3.9/25.4 MB 5.2 MB/s eta 0:00:05
#    ------- -------------------------------- 5.0/25.4 MB 5.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 7.1/25.4 MB 5.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 7.6/25.4 MB 5.4 MB/s eta 0:00:04
#    -------------- ------------------------- 9.4/25.4 MB 5.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 10.5/25.4 MB 5.9 MB/s eta 0:00:03
#    -------------------- ------------------- 12.8/25.4 MB 6.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 14.2/25.4 MB 6.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 15.2/25.4 MB 6.3 MB/s eta 0:00:02
#    ------------------------- -------------- 16.5/25.4 MB 6.3 MB/s eta 0:00:02
#    --------------------------- ------------ 17.3/25.4 MB 6.0 MB/s eta 0:00:02
#    ------------------------------ --------- 19.7/25.4 MB 6.4 MB/s eta 0:00:01
#    ------------------------------- -------- 19.9/25.4 MB 6.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 22.8/25.4 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------- -- 24.1/25.4 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------  25.4/25.4 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  25.4/25.4 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  25.4/25.4 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  25.4/25.4 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  25.4/25.4 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  25.4/25.4 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  25.4/25.4 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 25.4/25.4 MB 4.6 MB/s eta 0:00:00
# Downloading contextily-1.6.2-py3-none-any.whl (17 kB)
# Downloading rasterstats-0.20.0-py3-none-any.whl (17 kB)
# Downloading descartes-1.1.0-py3-none-any.whl (5.8 kB)
# Using cached branca-0.8.1-py3-none-any.whl (26 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Using cached pyogrio-0.10.0-cp312-cp312-win_amd64.whl (16.2 MB)
# Using cached pyproj-3.7.1-cp312-cp312-win_amd64.whl (6.3 MB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading simplejson-3.20.1-cp312-cp312-win_amd64.whl (75 kB)
# Using cached xyzservices-2025.1.0-py3-none-any.whl (88 kB)
# Using cached charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl (102 kB)
# Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached urllib3-2.3.0-py3-none-any.whl (128 kB)
# Installing collected packages: xyzservices, urllib3, simplejson, shapely, joblib, idna, geographiclib, click, charset-normalizer, certifi, affine, requests, pyproj, pyogrio, mercantile, geopy, cligj, click-plugins, branca, rasterio, geopandas, folium, fiona, descartes, rasterstats, contextily
# Successfully installed affine-2.4.0 branca-0.8.1 certifi-2025.1.31 charset-normalizer-3.4.1 click-8.1.8 click-plugins-1.1.1 cligj-0.7.2 contextily-1.6.2 descartes-1.1.0 fiona-1.10.1 folium-0.19.5 geographiclib-2.0 geopandas-1.0.1 geopy-2.4.1 idna-3.10 joblib-1.4.2 mercantile-1.2.1 pyogrio-0.10.0 pyproj-3.7.1 rasterio-1.4.3 rasterstats-0.20.0 requests-2.32.3 shapely-2.0.7 simplejson-3.20.1 urllib3-2.3.0 xyzservices-2025.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import rasterio
import geopandas as gpd

# %%
nepal='./Shape_Data/local_unit.shp'
df=gpd.read_file('./Shape_Data/local_unit.shp')
df.head()
# Out:
#    STATE_CODE   DISTRICT        GaPa_NaPa     Type_GN Province  \
# 0           1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika        1
# 1           1  TAPLEJUNG       Maiwakhola  Gaunpalika        1
# 2           1  TAPLEJUNG        Meringden  Gaunpalika        1
# 3           1  TAPLEJUNG       Mikwakhola  Gaunpalika        1
# 4           1  TAPLEJUNG     Phaktanglung  Gaunpalika        1
#
#                                             geometry
# 0  POLYGON ((87.60985 27.37043, 87.61107 27.36943...
# 1  POLYGON ((87.50402 27.42901, 87.50672 27.42831...
# 2  POLYGON ((87.51272 27.56894, 87.51255 27.56859...
# 3  POLYGON ((87.6885 27.70975, 87.68891 27.70938,...
# 4  POLYGON ((87.83673 27.95137, 87.83735 27.95119...

# %%
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   STATE_CODE  777 non-null    int32
#  1   DISTRICT    777 non-null    object
#  2   GaPa_NaPa   777 non-null    object
#  3   Type_GN     777 non-null    object
#  4   Province    777 non-null    object
#  5   geometry    777 non-null    geometry
# dtypes: geometry(1), int32(1), object(4)
# memory usage: 33.5+ KB

# %%
df.crs
# Out:
# <Geographic 2D CRS: GEOGCS["NepalDD",DATUM["D_Everest_Bangladesh",SPHE ...>
# Name: NepalDD
# Axis Info [ellipsoidal]:
# - lon[east]: Longitude (Degree)
# - lat[north]: Latitude (Degree)
# Area of Use:
# - undefined
# Datum: D_Everest_Bangladesh
# - Ellipsoid: Everest 1830 (1937 Adjustment)
# - Prime Meridian: Greenwich

# %%
df.geometry
# Out:
# 0      POLYGON ((87.60985 27.37043, 87.61107 27.36943...
# 1      POLYGON ((87.50402 27.42901, 87.50672 27.42831...
# 2      POLYGON ((87.51272 27.56894, 87.51255 27.56859...
# 3      POLYGON ((87.6885 27.70975, 87.68891 27.70938,...
# 4      POLYGON ((87.83673 27.95137, 87.83735 27.95119...
#                              ...
# 772    POLYGON ((84.32537 27.68957, 84.32562 27.6894,...
# 773    POLYGON ((82.65382 28.65759, 82.65428 28.65724...
# 774    POLYGON ((82.76718 28.80407, 82.76748 28.80383...
# 775    POLYGON ((82.67327 28.85214, 82.67373 28.85205...
# 776    POLYGON ((82.87365 28.83199, 82.87402 28.83178...
# Name: geometry, Length: 777, dtype: geometry

# %%
df.describe()
# Out:
#        STATE_CODE
# count  777.000000
# mean     3.651223
# std      2.000799
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      5.000000
# max      7.000000

# %%
df.isnull().sum() #checking for missing values if any
# Out:
# STATE_CODE    0
# DISTRICT      0
# GaPa_NaPa     0
# Type_GN       0
# Province      0
# geometry      0
# dtype: int64

# %%
ax=df.plot(figsize=(14,8), column='DISTRICT',edgecolor='white',alpha=0.9)
ax.set_ylabel('Latitude')
ax.set_xlabel('Longitude')
ax.set_title('Boundary of Nepal with districts')
plt.show()

# %%
df.plot(figsize=(14,8), column='Type_GN',legend=True,cmap='Paired',edgecolor='black',alpha=0.9)
plt.title('Nepal boundaries with various landmarks')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
precipitation_path_2020="./nepal_climate_data/nepal_precipitation_2020.tif"
precipitation_path_2050="./nepal_climate_data/nepal_precipitation_2050.tif"
temperature_path_2020="./nepal_climate_data/nepal_temperature_2020.tif"
temperature_path_2050="./nepal_climate_data/nepal_temperature_2050.tif"

# %%
#Load temperature data from tif file
with rasterio.open(temperature_path_2020) as src1:
    temp_data=src1.read(4) #read the 4th band (temperature data), most appropriate min/max
    extent=src1.bounds #get the extend of raster data ie top bottom left right

#printing the shape and extend of the raster data
print(f"Shape of the raster data : {temp_data.shape}")
print(f"extend of the raster data : {extent}")

#checking out the min and max temp
min_temp=np.min(temp_data)
max_temp=np.max(temp_data)
print(f"Minumum temperature : {min_temp}")
print(f"Maximum temperature : {max_temp}")
# Out:
# Shape of the raster data : (200, 400)
# extend of the raster data : BoundingBox(left=80.0, bottom=26.3, right=88.2, top=30.5)
# Minumum temperature : -15.461176406160137
# Maximum temperature : 16.05297897078062

# %%
# Plot the temperature data using imshow and overlay on Nepal's shapefile
fig, ax = plt.subplots(figsize=(14, 8))

# Plotting Nepal map (shapefile)
df.plot(ax=ax, edgecolor="black", facecolor="white", alpha=0.4)

# Plotting temperature data (TIFF) on top of the map of Nepal's boundaries with manual color scaling
im = ax.imshow(temp_data, cmap="coolwarm", extent=[extent.left, extent.right, extent.bottom, extent.top], vmin=min_temp, vmax=max_temp)

# Adding colorbar (Legend)
cbar = plt.colorbar(im, ax=ax)
cbar.set_label("Temperature (°C)")

# Set title and labels
ax.set_title("Nepal Temperature Gradient in year 2020")
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
plt.show()

# %% [markdown]
# # Analysis from above Nepal's temperature gradient
#
# - It is seen that from the data taken for analysis the plotted image shows that the temperature reaches to higher 15 degrees celcius at the north whereas the south is facing negative temperatures which is practically incorrect. Since, At the south lies the cities like Nepalgunj, Butwal, Biratnagar, Birgunj for which the temperature reaches to the max of 40-45 degrees in summers and to the north lies the Himalayas where the temperature should have been in negative.

# %%
#Load precipitation data from .tif file
with rasterio.open(precipitation_path_2020) as src2:
    precp_data=src2.read(4) #reading the 4rd band precipitation data
    extent_precp =src2.bounds #get the extent of precipitation raster data ie top bottom left right

#displaying the shape, extents minimum and maximum values of the raster data
print(f"The shape of the precipitaion raster data is : {precp_data.shape}")
print(f"The extent of precipitation raster data is : {extent_precp}")
min_precp=np.min(precp_data)
max_precp=np.max(precp_data)
print(f"The minimum value is : {min_precp}")
print(f"The maximum value is : {max_precp}")
# Out:
# The shape of the precipitaion raster data is : (200, 400)
# The extent of precipitation raster data is : BoundingBox(left=80.0, bottom=26.3, right=88.2, top=30.5)
# The minimum value is : 20.64714600913425
# The maximum value is : 311.1281914708154

# %%
#plotting the Nepal's vector data(shape file) overlaying the precipitaion raster data (tif file)
fig,ax=plt.subplots(figsize=(14,8))
df.plot(ax=ax,edgecolor='white',facecolor='none',alpha = 0.9) #Plotting the Nepal's vector data
ax.set_title('Precipitaion in Nepal in year 2020')#setting the title of the plot
ax.set_xlabel('Longitude')
ax.set_ylabel('Lattitude')

#Using the imshow function of pyplot module in matplotlib to display the data in image format (raster data)
im2=plt.imshow(precp_data,extent=[extent_precp.left,extent_precp.right,extent_precp.bottom,extent_precp.top],cmap='inferno',vmin=min_precp,vmax=max_precp)

#setting up the colorbar
cbar=plt.colorbar(im2,ax=ax)
cbar.set_label('Precipitation in mm (rainfall)')
